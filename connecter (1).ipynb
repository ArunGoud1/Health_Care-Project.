# %%
# !pip install mysql-connector

# %%
import mysql.connector
import pandas as pd
import seaborn as sns

# %%
db=mysql.connector.connect(
    host ="localhost",
    user = "root",
    password ="Arun@2144",
    database = "health_care",
    auth_plugin ='mysql_native_password',
    use_pure = True
)


mycursor = db.cursor()
print(db)

# %%
mycursor.execute("select * from docter")
output = mycursor.fetchall()
for x in output:
    print(x)
# Out:
# (1, 'Dr. V. Verma', 'Orthopedic', 'MD', 34, 'LIC-196585', 'AIIMS', 8737039810, 'Ahmedabad')
# (2, 'Dr. S. Iyer', 'Orthopedic', 'MD', 40, 'LIC-918205', 'AIIMS', 7678404134, 'Chennai')
# (3, 'Dr. R. Sharma', 'Cardiologist', 'DNB', 12, 'LIC-317168', 'Fortis Healthcare', 7987943602, 'Ahmedabad')
# (4, 'Dr. M. Reddy', 'Psychiatrist', 'DNB', 36, 'LIC-675484', 'Lilavati Hospital', 9048970723, 'Hyderabad')
# (5, 'Dr. A. Kumar', 'ENT Specialist', 'MCh', 17, 'LIC-991447', 'Manipal Hospital', 8736655300, 'Ahmedabad')
# (6, 'Dr. L. Singh', 'General Physician', 'DNB', 14, None, 'Narayana Health', 8994719885, 'Hyderabad')
# (7, 'Dr. A. Kumar', 'Gastroenterologist', 'DM', 13, 'LIC-608096', 'AIIMS', 7320584729, 'Ahmedabad')
# (8, 'Dr. N. Gupta', 'General Physician', 'DNB', 22, 'LIC-721567', 'Lilavati Hospital', 9258373374, 'Bangalore')
# (9, 'Dr. P. Patel', 'Dermatologist', 'MBBS', 2, 'LIC-252587', 'Fortis Healthcare', 8533109577, 'Ahmedabad')
# ...

# %% [markdown]
# # --------------"DOCTER_TABLE"------------

# %%
query = "select * from docter"
data =pd.read_sql(query,db)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_21320\792495468.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data =pd.read_sql(query,db)

# %%
data.head()
# Out:
#    S_No    Docter_Name  Specialization Degree  Experiance  Licence_NO  \
# 0     1   Dr. V. Verma      Orthopedic     MD          34  LIC-196585
# 1     2    Dr. S. Iyer      Orthopedic     MD          40  LIC-918205
# 2     3  Dr. R. Sharma    Cardiologist    DNB          12  LIC-317168
# 3     4   Dr. M. Reddy    Psychiatrist    DNB          36  LIC-675484
# 4     5   Dr. A. Kumar  ENT Specialist    MCh          17  LIC-991447
#
#        Hospital_Name  Contact_No   Location
# 0              AIIMS  8737039810  Ahmedabad
# 1              AIIMS  7678404134    Chennai
# 2  Fortis Healthcare  7987943602  Ahmedabad
# 3  Lilavati Hospital  9048970723  Hyderabad
# 4   Manipal Hospital  8736655300  Ahmedabad

# %%
data.tail()
# Out:
#      S_No   Docter_Name      Specialization Degree  Experiance  Licence_NO  \
# 295   296  Dr. L. Singh          Orthopedic    MCh          16  LIC-282001
# 296   297  Dr. V. Verma        Pediatrician    DNB          25  LIC-652500
# 297   298  Dr. P. Patel  Gastroenterologist    DNB          18  LIC-425909
# 298   299  Dr. N. Gupta       Dermatologist    MCh          18  LIC-886331
# 299   300  Dr. V. Verma  Gastroenterologist     MS          30  LIC-157557
#
#          Hospital_Name  Contact_No Location
# 295  Lilavati Hospital  9382857607     Pune
# 296    Narayana Health  8971338619  Kolkata
# 297       Max Hospital  9565508765     Pune
# 298  Fortis Healthcare  9787757381  Lucknow
# 299              AIIMS  8525003744   Jaipur

# %%
data.describe()
# Out:
#              S_No  Experiance    Contact_No
# count  300.000000  300.000000  3.000000e+02
# mean   150.500000   19.100000  8.511232e+09
# std     86.746758   11.398967  8.449178e+08
# min      1.000000    1.000000  7.011911e+09
# 25%     75.750000    9.000000  7.740638e+09
# 50%    150.500000   17.500000  8.521959e+09
# 75%    225.250000   29.000000  9.240157e+09
# max    300.000000   40.000000  9.989018e+09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S_No            300 non-null    int64
#  1   Docter_Name     300 non-null    object
#  2   Specialization  300 non-null    object
#  3   Degree          300 non-null    object
#  4   Experiance      300 non-null    int64
#  5   Licence_NO      293 non-null    object
#  6   Hospital_Name   300 non-null    object
#  7   Contact_No      300 non-null    int64
#  8   Location        300 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 21.2+ KB

# %%
data.isna().any()
# Out:
# S_No              False
# Docter_Name       False
# Specialization    False
# Degree            False
# Experiance        False
# Licence_NO         True
# Hospital_Name     False
# Contact_No        False
# Location          False
# dtype: bool

# %%
data.shape
# Out:
# (300, 9)

# %%
data.columns
# Out:
# Index(['S_No', 'Docter_Name', 'Specialization', 'Degree', 'Experiance',
#        'Licence_NO', 'Hospital_Name', 'Contact_No', 'Location'],
#       dtype='object')

# %%
data.isna()
# Out:
#       S_No  Docter_Name  Specialization  Degree  Experiance  Licence_NO  \
# 0    False        False           False   False       False       False
# 1    False        False           False   False       False       False
# 2    False        False           False   False       False       False
# 3    False        False           False   False       False       False
# 4    False        False           False   False       False       False
# ..     ...          ...             ...     ...         ...         ...
# 295  False        False           False   False       False       False
# 296  False        False           False   False       False       False
# 297  False        False           False   False       False       False
# 298  False        False           False   False       False       False
# 299  False        False           False   False       False       False
#
#      Hospital_Name  Contact_No  Location
# 0            False       False     False
# ...

# %%
data.isna().sum()
# Out:
# S_No              0
# Docter_Name       0
# Specialization    0
# Degree            0
# Experiance        0
# Licence_NO        7
# Hospital_Name     0
# Contact_No        0
# Location          0
# dtype: int64

# %%
data['Licence_NO'].isna().sum()
# Out:
# 7

# %%
data.fillna(method = "ffill",inplace = True)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_2992\273490641.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method = "ffill",inplace = True)

# %%
print(data.shape)
# Out:
# (300, 9)

# %%
data.isnull().sum()
# Out:
# S_No              0
# Docter_Name       0
# Specialization    0
# Degree            0
# Experiance        0
# Licence_NO        0
# Hospital_Name     0
# Contact_No        0
# Location          0
# dtype: int64

# %% [markdown]
# ## QUESTIONS
# 1) What is the average experience of doctors grouped by specialization?
# 2) Which hospital has the most diverse specializations represented
# 3) What is the most common degree among doctors in this dataset?
# 4) What is the relationship between specialization and the hospitals they are affiliated with?

# %% [markdown]
# ## 1) What is the average experience of doctors grouped by specialization?

# %%
data.head()
# Out:
#    S_No    Docter_Name  Specialization Degree  Experiance  Licence_NO  \
# 0     1   Dr. V. Verma      Orthopedic     MD          34  LIC-196585
# 1     2    Dr. S. Iyer      Orthopedic     MD          40  LIC-918205
# 2     3  Dr. R. Sharma    Cardiologist    DNB          12  LIC-317168
# 3     4   Dr. M. Reddy    Psychiatrist    DNB          36  LIC-675484
# 4     5   Dr. A. Kumar  ENT Specialist    MCh          17  LIC-991447
#
#        Hospital_Name  Contact_No   Location
# 0              AIIMS  8737039810  Ahmedabad
# 1              AIIMS  7678404134    Chennai
# 2  Fortis Healthcare  7987943602  Ahmedabad
# 3  Lilavati Hospital  9048970723  Hyderabad
# 4   Manipal Hospital  8736655300  Ahmedabad

# %%
data['Specialization'].value_counts()
# Out:
# Specialization
# General Physician     37
# Gastroenterologist    35
# Orthopedic            33
# Cardiologist          33
# Pediatrician          32
# ENT Specialist        31
# Neurologist           28
# Psychiatrist          26
# Dermatologist         24
# Oncologist            21
# Name: count, dtype: int64

# %%
data['Experiance'].value_counts()
# Out:
# Experiance
# 12    14
# 4     13
# 9     11
# 8     11
# 10    11
# 34    10
# 31    10
# 16    10
# 21    10
# 13    10
# 40    10
# 11    10
# 15     9
# 27     9
# 29     9
# 6      8
# 7      8
# 25     8
# 3      8
# 33     8
# 20     7
# 39     7
# 5      7
# 19     6
# 18     6
# 26     6
# 14     6
# 28     6
# 35     5
# 23     5
# 37     5
# 32     5
# 1      5
# 24     5
# 2      5
# 22     4
# 17     4
# 36     4
# 38     3
# 30     2
# Name: count, dtype: int64

# %%
Exp = data.groupby("Specialization")["Experiance"].mean()

# %%
A = Exp

# %%
A
# Out:
# Specialization
# Cardiologist          20.121212
# Dermatologist         18.041667
# ENT Specialist        15.161290
# Gastroenterologist    19.400000
# General Physician     20.702703
# Neurologist           17.535714
# Oncologist            21.476190
# Orthopedic            21.121212
# Pediatrician          16.250000
# Psychiatrist          21.500000
# Name: Experiance, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (18,8))
sns.barplot(data = data, x="Specialization",y="Experiance")  
plt.title("average experience of doctors grouped by specialization")
plt.show()

# %% [markdown]
# ## 2)  Which hospital has the most diverse specializations represented ?

# %%
data.head()
# Out:
#    S_No    Docter_Name  Specialization Degree  Experiance  Licence_NO  \
# 0     1   Dr. V. Verma      Orthopedic     MD          34  LIC-196585
# 1     2    Dr. S. Iyer      Orthopedic     MD          40  LIC-918205
# 2     3  Dr. R. Sharma    Cardiologist    DNB          12  LIC-317168
# 3     4   Dr. M. Reddy    Psychiatrist    DNB          36  LIC-675484
# 4     5   Dr. A. Kumar  ENT Specialist    MCh          17  LIC-991447
#
#        Hospital_Name  Contact_No   Location
# 0              AIIMS  8737039810  Ahmedabad
# 1              AIIMS  7678404134    Chennai
# 2  Fortis Healthcare  7987943602  Ahmedabad
# 3  Lilavati Hospital  9048970723  Hyderabad
# 4   Manipal Hospital  8736655300  Ahmedabad

# %%
hospital = data.groupby('Hospital_Name')['Specialization'].nunique()

# %%
hospital
# Out:
# Hospital_Name
# AIIMS                10
# Apollo Hospital       9
# Care Hospitals       10
# Fortis Healthcare    10
# KIMS                  8
# Lilavati Hospital    10
# Manipal Hospital     10
# Max Hospital          9
# Medanta              10
# Narayana Health       9
# Name: Specialization, dtype: int64

# %%
df = pd.DataFrame(hospital)

# %%
df
# Out:
#                    Specialization
# Hospital_Name
# AIIMS                          10
# Apollo Hospital                 9
# Care Hospitals                 10
# Fortis Healthcare              10
# KIMS                            8
# Lilavati Hospital              10
# Manipal Hospital               10
# Max Hospital                    9
# Medanta                        10
# Narayana Health                 9

# %%
sns.pairplot(data=df)

# %%
sns.heatmap(data=df)
# Out:
# <Axes: ylabel='Hospital_Name'>

# %% [markdown]
# ## 3) What is the most common degree among doctors in this dataset?

# %%
data.head()
# Out:
#    S_No    Docter_Name  Specialization Degree  Experiance  Licence_NO  \
# 0     1   Dr. V. Verma      Orthopedic     MD          34  LIC-196585
# 1     2    Dr. S. Iyer      Orthopedic     MD          40  LIC-918205
# 2     3  Dr. R. Sharma    Cardiologist    DNB          12  LIC-317168
# 3     4   Dr. M. Reddy    Psychiatrist    DNB          36  LIC-675484
# 4     5   Dr. A. Kumar  ENT Specialist    MCh          17  LIC-991447
#
#        Hospital_Name  Contact_No   Location
# 0              AIIMS  8737039810  Ahmedabad
# 1              AIIMS  7678404134    Chennai
# 2  Fortis Healthcare  7987943602  Ahmedabad
# 3  Lilavati Hospital  9048970723  Hyderabad
# 4   Manipal Hospital  8736655300  Ahmedabad

# %%
data['Degree']
# Out:
# 0       MD
# 1       MD
# 2      DNB
# 3      DNB
# 4      MCh
#       ...
# 295    MCh
# 296    DNB
# 297    DNB
# 298    MCh
# 299     MS
# Name: Degree, Length: 300, dtype: object

# %%
D = data['Degree'].value_counts()

# %%
D
# Out:
# Degree
# MBBS    60
# DNB     58
# DM      50
# MCh     46
# MD      45
# MS      41
# Name: count, dtype: int64

# %%
sns.barplot(data=D)
# Out:
# <Axes: xlabel='Degree', ylabel='count'>

# %%
d = pd.DataFrame(D)

# %%
d
# Out:
#         count
# Degree
# MBBS       60
# DNB        58
# DM         50
# MCh        46
# MD         45
# MS         41

# %%
sns.heatmap(data=d)
# Out:
# <Axes: ylabel='Degree'>

# %% [markdown]
# ## 4) What is the relationship between specialization and the hospitals they are affiliated with?

# %%
data.head()
# Out:
#    S_No    Docter_Name  Specialization Degree  Experiance  Licence_NO  \
# 0     1   Dr. V. Verma      Orthopedic     MD          34  LIC-196585
# 1     2    Dr. S. Iyer      Orthopedic     MD          40  LIC-918205
# 2     3  Dr. R. Sharma    Cardiologist    DNB          12  LIC-317168
# 3     4   Dr. M. Reddy    Psychiatrist    DNB          36  LIC-675484
# 4     5   Dr. A. Kumar  ENT Specialist    MCh          17  LIC-991447
#
#        Hospital_Name  Contact_No   Location
# 0              AIIMS  8737039810  Ahmedabad
# 1              AIIMS  7678404134    Chennai
# 2  Fortis Healthcare  7987943602  Ahmedabad
# 3  Lilavati Hospital  9048970723  Hyderabad
# 4   Manipal Hospital  8736655300  Ahmedabad

# %%
plt.figure(figsize = (14,20))
sns.relplot(data= data ,x="Specialization", y="Hospital_Name")  
plt.title("Relationship between specialization and the hospitals they are affiliated with")
plt.show()

# %%
plt.figure(figsize = (18,8))
sns.barplot(data= data ,x="Specialization", y="Hospital_Name")  
plt.title("Relationship between specialization and the hospitals they are affiliated with")
plt.show()

# %%
plt.figure(figsize = (18,8))
sns.boxplot(data= data ,x="Specialization", y="Hospital_Name")  
plt.title("Relationship between specialization and the hospitals they are affiliated with")
plt.show()

# %% [markdown]
# # --------------"EMPLOYE_TABLE"------------

# %%
query = "select * from employe"
Employe =pd.read_sql(query,db)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_2696\4075913867.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Employe =pd.read_sql(query,db)

# %%
Employe.head()
# Out:
#    S_No       Employee_Name   Department Designation  Salary  Contact_No  \
# 0     1         Gokul Jaggi   Pediatrics       Nurse  181041  9291198286
# 1     2  Hunar Ramakrishnan  Orthopedics  Technician   88137  8541603908
# 2     3           Azad Saha   Cardiology      Doctor  183703  7720931992
# 3     4        Vanya Sastry     Pharmacy       Nurse  125061  8538138925
# 4     5         Himmat Wali   Pediatrics       Nurse   56068  8871845663
#
#      Joining_Date Location
# 0  \t15-12-2020\t  Kolkata
# 1  \t08-02-2016\t  Kolkata
# 2  \t29-03-2024\t     Pune
# 3  \t12-04-2018\t   Mumbai
# 4  \t12-01-2018\t     Pune

# %%
Employe.tail()
# Out:
#      S_No  Employee_Name  Department    Designation  Salary  Contact_No  \
# 495   496    Ishita Jani   Neurology          Nurse   41074  8729196676
# 496   497   Shaan Shenoy   Radiology     Technician  112146  9698816462
# 497   498   Dhanush Gade   Radiology  Lab Assistant  197192  7376617004
# 498   499  Vedika Chawla  Cardiology     Pharmacist   41752  9855652355
# 499   500    Emir Sastry   Emergency         Doctor  129311  7402462272
#
#        Joining_Date   Location
# 495  \t09-04-2015\t  Ahmedabad
# 496  \t26-01-2024\t    Kolkata
# 497  \t09-01-2021\t       Pune
# 498  \t29-01-2016\t    Chennai
# 499  \t05-04-2015\t    Chennai

# %%
Employe.describe()
# Out:
#              S_No         Salary    Contact_No
# count  500.000000     500.000000  5.000000e+02
# mean   250.500000  112883.766000  8.494400e+09
# std    144.481833   51211.166288  8.606922e+08
# min      1.000000   25277.000000  7.007603e+09
# 25%    125.750000   67308.750000  7.753057e+09
# 50%    250.500000  117505.000000  8.528460e+09
# 75%    375.250000  157648.000000  9.239914e+09
# max    500.000000  198030.000000  9.993727e+09

# %%
Employe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   S_No           500 non-null    int64
#  1   Employee_Name  500 non-null    object
#  2   Department     500 non-null    object
#  3   Designation    500 non-null    object
#  4   Salary         500 non-null    int64
#  5   Contact_No     500 non-null    int64
#  6   Joining_Date   500 non-null    object
#  7   Location       500 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 31.4+ KB

# %%
Employe.isna().any()
# Out:
# S_No             False
# Employee_Name    False
# Department       False
# Designation      False
# Salary           False
# Contact_No       False
# Joining_Date     False
# Location         False
# dtype: bool

# %%
Employe.shape
# Out:
# (500, 8)

# %%
Employe.columns
# Out:
# Index(['S_No', 'Employee_Name', 'Department', 'Designation', 'Salary',
#        'Contact_No', 'Joining_Date', 'Location'],
#       dtype='object')

# %%
Employe.isna()
# Out:
#       S_No  Employee_Name  Department  Designation  Salary  Contact_No  \
# 0    False          False       False        False   False       False
# 1    False          False       False        False   False       False
# 2    False          False       False        False   False       False
# 3    False          False       False        False   False       False
# 4    False          False       False        False   False       False
# ..     ...            ...         ...          ...     ...         ...
# 495  False          False       False        False   False       False
# 496  False          False       False        False   False       False
# 497  False          False       False        False   False       False
# 498  False          False       False        False   False       False
# 499  False          False       False        False   False       False
#
#      Joining_Date  Location
# 0           False     False
# 1           False     False
# ...

# %%
Employe.isna().sum()
# Out:
# S_No             0
# Employee_Name    0
# Department       0
# Designation      0
# Salary           0
# Contact_No       0
# Joining_Date     0
# Location         0
# dtype: int64

# %% [markdown]
# ## QUESTIONS
#  1) What is the average salary by department?
#  2) How many employees are in each designation?
#  3) What is the salary distribution by location?
#  4) Who has the highest salary in each department?

# %% [markdown]
# ## 1) What is the average salary by department?

# %%
Employe.head()
# Out:
#    S_No       Employee_Name   Department Designation  Salary  Contact_No  \
# 0     1         Gokul Jaggi   Pediatrics       Nurse  181041  9291198286
# 1     2  Hunar Ramakrishnan  Orthopedics  Technician   88137  8541603908
# 2     3           Azad Saha   Cardiology      Doctor  183703  7720931992
# 3     4        Vanya Sastry     Pharmacy       Nurse  125061  8538138925
# 4     5         Himmat Wali   Pediatrics       Nurse   56068  8871845663
#
#      Joining_Date Location
# 0  \t15-12-2020\t  Kolkata
# 1  \t08-02-2016\t  Kolkata
# 2  \t29-03-2024\t     Pune
# 3  \t12-04-2018\t   Mumbai
# 4  \t12-01-2018\t     Pune

# %%
Employee = pd.DataFrame(Employe)

# %%
E =Employee.groupby('Department')['Salary'].sum()

# %%
E
# Out:
# Department
# Cardiology     6582782
# Emergency      6217449
# Neurology      7213761
# Oncology       7762623
# Orthopedics    7692218
# Pediatrics     7025854
# Pharmacy       6595366
# Radiology      7351830
# Name: Salary, dtype: int64

# %%
e =Employee.groupby('Department')['Salary'].mean().round(2)

# %%
e
# Out:
# Department
# Cardiology     107914.46
# Emergency      101925.39
# Neurology      116350.98
# Oncology       119424.97
# Orthopedics    120190.91
# Pediatrics     121135.41
# Pharmacy       106376.87
# Radiology      109728.81
# Name: Salary, dtype: float64

# %%
plt.figure(figsize = (18,8))
sns.barplot(data=e)  
plt.title("Average salary by department")
plt.show()

# %%
d = pd.DataFrame(e)

# %%
plt.figure(figsize = (14,8))
sns.relplot(data=d, x="Department", y="Salary",hue = "Salary", kind="line" )  
plt.title("Average salary by department")
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.relplot(data=d, x="Department", y="Salary",kind="line" )

# %% [markdown]
# ## 2) How many employees are in each designation?

# %%
Employe.head()
# Out:
#    S_No       Employee_Name   Department Designation  Salary  Contact_No  \
# 0     1         Gokul Jaggi   Pediatrics       Nurse  181041  9291198286
# 1     2  Hunar Ramakrishnan  Orthopedics  Technician   88137  8541603908
# 2     3           Azad Saha   Cardiology      Doctor  183703  7720931992
# 3     4        Vanya Sastry     Pharmacy       Nurse  125061  8538138925
# 4     5         Himmat Wali   Pediatrics       Nurse   56068  8871845663
#
#      Joining_Date Location
# 0  \t15-12-2020\t  Kolkata
# 1  \t08-02-2016\t  Kolkata
# 2  \t29-03-2024\t     Pune
# 3  \t12-04-2018\t   Mumbai
# 4  \t12-01-2018\t     Pune

# %%
Employe['Designation'].unique()
# Out:
# array(['Nurse', 'Technician', 'Doctor', 'Pharmacist',
#        'Administrative Staff', 'Lab Assistant', 'Receptionist'],
#       dtype=object)

# %%
Designation = Employe['Designation'].value_counts()

# %%
Designation
# Out:
# Designation
# Lab Assistant           82
# Doctor                  77
# Pharmacist              75
# Receptionist            75
# Nurse                   72
# Technician              62
# Administrative Staff    57
# Name: count, dtype: int64

# %%
plt.figure(figsize = (18,8))
sns.barplot(data=Designation)  
plt.title("Employees in each Designation")
plt.show()

# %%
Desig = pd.DataFrame(Designation)

# %%
Desig
# Out:
#                       count
# Designation
# Lab Assistant            82
# Doctor                   77
# Pharmacist               75
# Receptionist             75
# Nurse                    72
# Technician               62
# Administrative Staff     57

# %%
plt.figure(figsize = (18,8))
sns.pairplot(data=Desig)  
plt.title("Employees in each Designation")
plt.show()

# %%
sns.heatmap(data=Desig)
# Out:
# <Axes: ylabel='Designation'>

# %% [markdown]
# ## 3) What is the salary distribution by location?

# %%
Emp = pd.DataFrame(Employe)

# %%
Emp.head()
# Out:
#    S_No       Employee_Name   Department Designation  Salary  Contact_No  \
# 0     1         Gokul Jaggi   Pediatrics       Nurse  181041  9291198286
# 1     2  Hunar Ramakrishnan  Orthopedics  Technician   88137  8541603908
# 2     3           Azad Saha   Cardiology      Doctor  183703  7720931992
# 3     4        Vanya Sastry     Pharmacy       Nurse  125061  8538138925
# 4     5         Himmat Wali   Pediatrics       Nurse   56068  8871845663
#
#      Joining_Date Location
# 0  \t15-12-2020\t  Kolkata
# 1  \t08-02-2016\t  Kolkata
# 2  \t29-03-2024\t     Pune
# 3  \t12-04-2018\t   Mumbai
# 4  \t12-01-2018\t     Pune

# %%
salary = Emp.groupby('Location')['Salary'].agg(['count', 'mean', 'min', 'max']).reset_index()

# %%
salary.columns = ['Location', 'Employee_Count', 'Average_Salary', 'Minimum_Salary', 'Maximum_Salary']

# %%
salary
# Out:
#     Location  Employee_Count  Average_Salary  Minimum_Salary  Maximum_Salary
# 0  Ahmedabad              59   112352.745763           31019          196285
# 1  Bangalore              64   115282.359375           29484          195837
# 2    Chennai              67   111930.641791           28537          194567
# 3      Delhi              53   103192.792453           25750          197884
# 4  Hyderabad              63   124265.968254           25443          196604
# 5    Kolkata              67   111978.910448           29760          194351
# 6     Mumbai              63   110406.269841           30473          195997
# 7       Pune              64   112179.546875           25277          198030

# %%
Salary = salary.groupby('Location')['Maximum_Salary'].mean()

# %%
Salary
# Out:
# Location
# Ahmedabad    196285.0
# Bangalore    195837.0
# Chennai      194567.0
# Delhi        197884.0
# Hyderabad    196604.0
# Kolkata      194351.0
# Mumbai       195997.0
# Pune         198030.0
# Name: Maximum_Salary, dtype: float64

# %%
plt.figure(figsize = (18,8))
sns.barplot(data= Salary)  
plt.title("The salary distribution by location")
plt.show()

# %%
# Find the employee with the highest salary in each department
highest_salary_by_department = df.loc[df.groupby('Department')['Salary'].idxmax()]

# Select relevant columns for readability
highest_salary_by_department = highest_salary_by_department[['Department', 'Employee_Name', 'Salary']]

# Display the result
print(highest_salary_by_department)

# %% [markdown]
# ##  4) Who has the highest salary in each department?

# %%
Employe.head()
# Out:
#    S_No       Employee_Name   Department Designation  Salary  Contact_No  \
# 0     1         Gokul Jaggi   Pediatrics       Nurse  181041  9291198286
# 1     2  Hunar Ramakrishnan  Orthopedics  Technician   88137  8541603908
# 2     3           Azad Saha   Cardiology      Doctor  183703  7720931992
# 3     4        Vanya Sastry     Pharmacy       Nurse  125061  8538138925
# 4     5         Himmat Wali   Pediatrics       Nurse   56068  8871845663
#
#      Joining_Date Location
# 0  \t15-12-2020\t  Kolkata
# 1  \t08-02-2016\t  Kolkata
# 2  \t29-03-2024\t     Pune
# 3  \t12-04-2018\t   Mumbai
# 4  \t12-01-2018\t     Pune

# %%
Highest_Salary = pd.DataFrame(Employe)

# %%
H = Highest_Salary.loc[Highest_Salary.groupby('Department')['Salary'].idxmax()]

# %%
H
# Out:
#      S_No    Employee_Name   Department           Designation  Salary  \
# 183   184     Prisha Ghosh   Cardiology                 Nurse  195837
# 43     44       Sana Magar    Emergency                 Nurse  194172
# 470   471       Myra Bhatt    Neurology  Administrative Staff  198030
# 295   296       Rhea Hayre     Oncology         Lab Assistant  194614
# 246   247  Saksham Kadakia  Orthopedics            Technician  196175
# 47     48      Kartik Dutt   Pediatrics         Lab Assistant  197884
# 427   428     Aradhya Bumb     Pharmacy                Doctor  196604
# 497   498     Dhanush Gade    Radiology         Lab Assistant  197192
#
#      Contact_No    Joining_Date   Location
# 183  8823258654  \t27-01-2024\t  Bangalore
# 43   8664595694  \t25-11-2023\t    Kolkata
# 470  7356729189  \t03-04-2018\t       Pune
# 295  9691120018  \t16-06-2018\t     Mumbai
# 246  7672355814  \t28-07-2016\t  Hyderabad
# 47   9694532199  \t20-12-2018\t      Delhi
# ...

# %%
h = H[['Department', 'Employee_Name', 'Salary']]

# %%
h
# Out:
#       Department    Employee_Name  Salary
# 183   Cardiology     Prisha Ghosh  195837
# 43     Emergency       Sana Magar  194172
# 470    Neurology       Myra Bhatt  198030
# 295     Oncology       Rhea Hayre  194614
# 246  Orthopedics  Saksham Kadakia  196175
# 47    Pediatrics      Kartik Dutt  197884
# 427     Pharmacy     Aradhya Bumb  196604
# 497    Radiology     Dhanush Gade  197192

# %%
plt.figure(figsize=(14, 8))
sns.barplot(
    data=h, 
    x="Department", 
    y="Salary",
    hue = "Salary"
)
plt.title(" The Highest salary in each Department")
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(data=h, 
    x="Department", 
    y="Salary",
    hue = "Salary")
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# # --------------"LAB_TABLE"------------

# %%
query = "select * from lab"
lab =pd.read_sql(query,db)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_16744\1932992692.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   lab =pd.read_sql(query,db)

# %%
lab.head()
# Out:
#    S_no Patient_id     Patient_name  Gender  Age       Test_date   Test_type  \
# 0     1      P5785        Erin Tran  Female   70  \t26-02-2024\t  Urine Test
# 1     2      P2143     Robert Gomez    Male   55  \t30-03-2024\t         MRI
# 2     3      P5451    Oscar Sanders    Male   65  \t13-10-2024\t     CT Scan
# 3     4      P7837  Andrea Crawford    Male   31  \t02-05-2024\t         MRI
# 4     5      P2380    Tonya Johnson    Male   76  \t26-05-2024\t  Ultrasound
#
#   Test_result   Dose Status_result            Comments
# 0        High   64.0   In Progress    Abnormal results
# 1    Abnormal    NaN       Pending  Requires follow-up
# 2        High  205.0       Pending  Requires follow-up
# 3    Abnormal    NaN     Completed  Requires follow-up
# 4      Normal    NaN       Pending                 N/A

# %%
lab.tail()
# Out:
#      S_no Patient_id      Patient_name Gender  Age       Test_date  \
# 595   596      P9670        Amy Foster   Male   34  \t08-12-2024\t
# 596   597      P9976   Shawn Singleton   Male   75  \t24-02-2024\t
# 597   598      P3231  Cassandra Murphy   Male   56  \t06-10-2024\t
# 598   599      P9789    Daniel Mahoney   Male   45  \t05-06-2024\t
# 599   600      P8657     Amanda Torres   Male   63  \t08-07-2024\t
#
#       Test_type Test_result   Dose Status_result              Comments
# 595       X-ray      Normal    NaN       Pending    Requires follow-up
# 596  Urine Test        High    NaN     Completed    Requires follow-up
# 597         MRI    Positive  171.0       Pending  Further tests needed
# 598  Urine Test    Negative  254.0       Pending    Requires follow-up
# 599         MRI        High  124.0     Completed    Requires follow-up

# %%
lab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   S_no           600 non-null    int64
#  1   Patient_id     600 non-null    object
#  2   Patient_name   600 non-null    object
#  3   Gender         600 non-null    object
#  4   Age            600 non-null    int64
#  5   Test_date      600 non-null    object
#  6   Test_type      600 non-null    object
#  7   Test_result    600 non-null    object
#  8   Dose           293 non-null    float64
#  9   Status_result  600 non-null    object
#  10  Comments       600 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 51.7+ KB

# %%
lab.describe()
# Out:
#              S_no         Age        Dose
# count  600.000000  600.000000  293.000000
# mean   300.500000   50.183333  158.191126
# std    173.349358   18.582031   81.379361
# min      1.000000   18.000000   11.000000
# 25%    150.750000   34.000000   89.000000
# 50%    300.500000   50.000000  162.000000
# 75%    450.250000   67.000000  220.000000
# max    600.000000   80.000000  299.000000

# %%
lab.isnull().any()
# Out:
# S_no             False
# Patient_id       False
# Patient_name     False
# Gender           False
# Age              False
# Test_date        False
# Test_type        False
# Test_result      False
# Dose              True
# Status_result    False
# Comments         False
# dtype: bool

# %%
lab['Dose'].isna()
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 595     True
# 596     True
# 597    False
# 598    False
# 599    False
# Name: Dose, Length: 600, dtype: bool

# %%
lab.isna().sum()
# Out:
# S_no               0
# Patient_id         0
# Patient_name       0
# Gender             0
# Age                0
# Test_date          0
# Test_type          0
# Test_result        0
# Dose             307
# Status_result      0
# Comments           0
# dtype: int64

# %%
lab['Dose'].isna().sum()
# Out:
# 307

# %%
lab.shape
# Out:
# (600, 11)

# %%
lab.fillna(method = "ffill",inplace = True)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_2696\1102285975.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   lab.fillna(method = "ffill",inplace = True)

# %%
lab.isna().sum()
# Out:
# S_no             0
# Patient_id       0
# Patient_name     0
# Gender           0
# Age              0
# Test_date        0
# Test_type        0
# Test_result      0
# Dose             0
# Status_result    0
# Comments         0
# dtype: int64

# %%
lab.shape
# Out:
# (600, 11)

# %%
lab=pd.DataFrame(lab)

# %%
lab
# Out:
#      S_no Patient_id      Patient_name  Gender  Age       Test_date  \
# 0       1      P5785         Erin Tran  Female   70  \t26-02-2024\t
# 1       2      P2143      Robert Gomez    Male   55  \t30-03-2024\t
# 2       3      P5451     Oscar Sanders    Male   65  \t13-10-2024\t
# 3       4      P7837   Andrea Crawford    Male   31  \t02-05-2024\t
# 4       5      P2380     Tonya Johnson    Male   76  \t26-05-2024\t
# ..    ...        ...               ...     ...  ...             ...
# 595   596      P9670        Amy Foster    Male   34  \t08-12-2024\t
# 596   597      P9976   Shawn Singleton    Male   75  \t24-02-2024\t
# 597   598      P3231  Cassandra Murphy    Male   56  \t06-10-2024\t
# 598   599      P9789    Daniel Mahoney    Male   45  \t05-06-2024\t
# 599   600      P8657     Amanda Torres    Male   63  \t08-07-2024\t
#
#       Test_type Test_result   Dose Status_result              Comments
# 0    Urine Test        High   64.0   In Progress      Abnormal results
# ...

# %%
lab.columns
# Out:
# Index(['S_no', 'Patient_id', 'Patient_name', 'Gender', 'Age', 'Test_date',
#        'Test_type', 'Test_result', 'Dose', 'Status_result', 'Comments'],
#       dtype='object')

# %% [markdown]
# ## QUESTIONS
#  1) What is the Correlation Between Test Types and Comments?
#  2) Which test type  is the most commonly performed? Does this vary by patient demographics like gender?
#  3) Which test types are more likely to yield abnormal or high results?
#  4) What percentage of tests are currently in the "Pending" status?
#  5) What are the most repeated comments  in the "Comments" column?

# %% [markdown]
# ## 1) What is the Correlation Between Test Types and Comments?

# %%
lab.head()
# Out:
#    S_no Patient_id     Patient_name  Gender  Age       Test_date   Test_type  \
# 0     1      P5785        Erin Tran  Female   70  \t26-02-2024\t  Urine Test
# 1     2      P2143     Robert Gomez    Male   55  \t30-03-2024\t         MRI
# 2     3      P5451    Oscar Sanders    Male   65  \t13-10-2024\t     CT Scan
# 3     4      P7837  Andrea Crawford    Male   31  \t02-05-2024\t         MRI
# 4     5      P2380    Tonya Johnson    Male   76  \t26-05-2024\t  Ultrasound
#
#   Test_result   Dose Status_result            Comments
# 0        High   64.0   In Progress    Abnormal results
# 1    Abnormal   64.0       Pending  Requires follow-up
# 2        High  205.0       Pending  Requires follow-up
# 3    Abnormal  205.0     Completed  Requires follow-up
# 4      Normal  205.0       Pending                 N/A

# %%
corrleation = lab.groupby(['Test_type', 'Comments']).size().reset_index(name='Count')

# %%
corrleation
# Out:
#      Test_type              Comments  Count
# 0   Blood Test      Abnormal results     21
# 1   Blood Test  Further tests needed     20
# 2   Blood Test                   N/A     27
# 3   Blood Test    Requires follow-up     32
# 4      CT Scan      Abnormal results     26
# 5      CT Scan  Further tests needed     23
# 6      CT Scan                   N/A     27
# 7      CT Scan    Requires follow-up     24
# 8          MRI      Abnormal results     21
# 9          MRI  Further tests needed     24
# 10         MRI                   N/A     27
# 11         MRI    Requires follow-up     29
# 12  Ultrasound      Abnormal results     18
# 13  Ultrasound  Further tests needed     24
# 14  Ultrasound                   N/A     31
# 15  Ultrasound    Requires follow-up     26
# 16  Urine Test      Abnormal results     19
# 17  Urine Test  Further tests needed     20
# 18  Urine Test                   N/A     28
# 19  Urine Test    Requires follow-up     31
# ...

# %%
 A=lab[['Age','Dose']].corr()

# %%
A
# Out:
#            Age      Dose
# Age   1.000000 -0.001173
# Dose -0.001173  1.000000

# %%
plt.figure(figsize=(14, 8))
sns.barplot(
    data=A, 
    x="Age", 
    y="Dose",
    hue = "Dose"
)
plt.title(" The Highest salary in each Department")
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.barplot(
    data=lab, 
    x="Age", 
    y="Dose",
    hue = "Dose"
)
plt.title(" The Highest salary in each Department")
plt.show()

# %% [markdown]
#  ## 2) Which test type  is the most commonly performed? Does this vary by patient demographics like  gender?

# %%
lab.head()
# Out:
#    S_no Patient_id     Patient_name  Gender  Age       Test_date   Test_type  \
# 0     1      P5785        Erin Tran  Female   70  \t26-02-2024\t  Urine Test
# 1     2      P2143     Robert Gomez    Male   55  \t30-03-2024\t         MRI
# 2     3      P5451    Oscar Sanders    Male   65  \t13-10-2024\t     CT Scan
# 3     4      P7837  Andrea Crawford    Male   31  \t02-05-2024\t         MRI
# 4     5      P2380    Tonya Johnson    Male   76  \t26-05-2024\t  Ultrasound
#
#   Test_result   Dose Status_result            Comments
# 0        High   64.0   In Progress    Abnormal results
# 1    Abnormal   64.0       Pending  Requires follow-up
# 2        High  205.0       Pending  Requires follow-up
# 3    Abnormal  205.0     Completed  Requires follow-up
# 4      Normal  205.0       Pending                 N/A

# %%
T = lab["Test_type"].value_counts()

# %%
T
# Out:
# Test_type
# X-ray         102
# MRI           101
# CT Scan       100
# Blood Test    100
# Ultrasound     99
# Urine Test     98
# Name: count, dtype: int64

# %%
Gender_Test = lab.groupby(["Gender", "Test_type"]).size()

# %%
Gender_Test
# Out:
# Gender  Test_type
# Female  Blood Test    42
#         CT Scan       53
#         MRI           52
#         Ultrasound    51
#         Urine Test    37
#         X-ray         46
# Male    Blood Test    58
#         CT Scan       47
#         MRI           49
#         Ultrasound    48
#         Urine Test    61
#         X-ray         56
# dtype: int64

# %%
Gender_test = lab.groupby(["Gender", "Test_type"]).size().unstack(fill_value=0)

# %%
Gender_test
# Out:
# Test_type  Blood Test  CT Scan  MRI  Ultrasound  Urine Test  X-ray
# Gender
# Female             42       53   52          51          37     46
# Male               58       47   49          48          61     56

# %%
sns.barplot(data = Gender_test)
# Out:
# <Axes: xlabel='Test_type'>

# %%
sns.boxplot(data = Gender_test)
# Out:
# <Axes: xlabel='Test_type'>

# %% [markdown]
# ## 3) Which test types are more likely to yield abnormal or high results?

# %%
lab.head()
# Out:
#    S_no Patient_id     Patient_name  Gender  Age       Test_date   Test_type  \
# 0     1      P5785        Erin Tran  Female   70  \t26-02-2024\t  Urine Test
# 1     2      P2143     Robert Gomez    Male   55  \t30-03-2024\t         MRI
# 2     3      P5451    Oscar Sanders    Male   65  \t13-10-2024\t     CT Scan
# 3     4      P7837  Andrea Crawford    Male   31  \t02-05-2024\t         MRI
# 4     5      P2380    Tonya Johnson    Male   76  \t26-05-2024\t  Ultrasound
#
#   Test_result   Dose Status_result            Comments
# 0        High   64.0   In Progress    Abnormal results
# 1    Abnormal    NaN       Pending  Requires follow-up
# 2        High  205.0       Pending  Requires follow-up
# 3    Abnormal    NaN     Completed  Requires follow-up
# 4      Normal    NaN       Pending                 N/A

# %%
abnormal_high = lab[lab["Test_result"].isin(["Abnormal", "High"])]

# %%
abnormal_high
# Out:
#      S_no Patient_id      Patient_name  Gender  Age       Test_date  \
# 0       1      P5785         Erin Tran  Female   70  \t26-02-2024\t
# 1       2      P2143      Robert Gomez    Male   55  \t30-03-2024\t
# 2       3      P5451     Oscar Sanders    Male   65  \t13-10-2024\t
# 3       4      P7837   Andrea Crawford    Male   31  \t02-05-2024\t
# 6       7      P1739      Anthony King  Female   71  \t13-11-2024\t
# ..    ...        ...               ...     ...  ...             ...
# 586   587      P1248    Jonathan Green    Male   58  \t09-04-2024\t
# 588   589      P7841  Alexander Kramer  Female   31  \t16-02-2024\t
# 591   592      P8912   Michael Preston  Female   74  \t27-03-2024\t
# 596   597      P9976   Shawn Singleton    Male   75  \t24-02-2024\t
# 599   600      P8657     Amanda Torres    Male   63  \t08-07-2024\t
#
#       Test_type Test_result   Dose Status_result              Comments
# 0    Urine Test        High   64.0   In Progress      Abnormal results
# ...

# %%
total_tests = lab["Test_type"].value_counts()

# %%
total_tests
# Out:
# Test_type
# X-ray         102
# MRI           101
# CT Scan       100
# Blood Test    100
# Ultrasound     99
# Urine Test     98
# Name: count, dtype: int64

# %%
abnormal_high_by_type = abnormal_high["Test_type"].value_counts()

# %%
abnormal_high_by_type
# Out:
# Test_type
# MRI           43
# CT Scan       40
# X-ray         37
# Ultrasound    32
# Urine Test    30
# Blood Test    30
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 8))
sns.barplot(
    data=abnormal_high_by_type
)
plt.title(" Abnormal_high_by_type")
plt.show()

# %%
sns.barplot(data = total_tests)
# Out:
# <Axes: xlabel='Test_type', ylabel='count'>

# %% [markdown]
# ## 4) What percentage of tests are currently in the "Pending" status?

# %%
Total_tests = len(lab)     # total number of Tests.

# %%
Total_tests
# Out:
# 600

# %%
pending_tests = len(lab[lab["Status_result"] == "Pending"])    # Count the number of tests with "Pending" status.

# %%
pending_tests
# Out:
# 191

# %%
percentage_pending = (pending_tests / total_tests) * (100)          # Calculate the percentage of pending tests

# %%
percentage_pending
# Out:
# 31.833333333333336

# %% [markdown]
# ## 5) What are the most repeated comments  in the "Comments" column?

# %%
lab.head()
# Out:
#    S_no Patient_id     Patient_name  Gender  Age       Test_date   Test_type  \
# 0     1      P5785        Erin Tran  Female   70  \t26-02-2024\t  Urine Test
# 1     2      P2143     Robert Gomez    Male   55  \t30-03-2024\t         MRI
# 2     3      P5451    Oscar Sanders    Male   65  \t13-10-2024\t     CT Scan
# 3     4      P7837  Andrea Crawford    Male   31  \t02-05-2024\t         MRI
# 4     5      P2380    Tonya Johnson    Male   76  \t26-05-2024\t  Ultrasound
#
#   Test_result   Dose Status_result            Comments
# 0        High   64.0   In Progress    Abnormal results
# 1    Abnormal    NaN       Pending  Requires follow-up
# 2        High  205.0       Pending  Requires follow-up
# 3    Abnormal    NaN     Completed  Requires follow-up
# 4      Normal    NaN       Pending                 N/A

# %%
comment_counts = lab["Comments"].value_counts()

# %%
comment_counts
# Out:
# Comments
# N/A                     176
# Requires follow-up      167
# Further tests needed    134
# Abnormal results        123
# Name: count, dtype: int64

# %%
most_repeated_comments = comment_counts.head(10)

# %%
most_repeated_comments
# Out:
# Comments
# N/A                     176
# Requires follow-up      167
# Further tests needed    134
# Abnormal results        123
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 8))
sns.barplot(
    data=most_repeated_comments
)
plt.title(" Most_Repeated_Comments")
plt.show()

# %% [markdown]
# # --------------"OP_TABLE"------------

# %%
query = "select * from op"
op =pd.read_sql(query,db)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_3628\2206753491.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   op =pd.read_sql(query,db)

# %%
op.head()
# Out:
#    s_no Appointment_id      Patient_name  Gender  Age Appointment_Date  \
# 0     1           0001        Tara Varma  Female   33   \t2024-12-22\t
# 1     2           0002        Purab Garg  Female   74   \t2024-01-17\t
# 2     3           0003   Indrajit Kalita    Male   88   \t2024-12-01\t
# 3     4           0004  Dharmajan Sankar    Male    7   \t2024-02-04\t
# 4     5           0005        Samar Wali  Female   35   \t2024-11-03\t
#
#   Appointment_Time    Docter_Assigned
# 0         03:09 AM   Dr. Sunita Nair
# 1         09:44 AM  Dr. Rajesh Gupta
# 2         01:18 PM   Dr. Mohit Kumar
# 3         06:45 PM    Dr. Pooja Iyer
# 4         11:58 AM   Dr. Sunita Nair

# %%
op.describe()
# Out:
#              s_no         Age
# count  777.000000  777.000000
# mean   389.000000   45.451737
# std    224.444871   26.067479
# min      1.000000    1.000000
# 25%    195.000000   23.000000
# 50%    389.000000   47.000000
# 75%    583.000000   67.000000
# max    777.000000   90.000000

# %%
op.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   s_no              777 non-null    int64
#  1   Appointment_id    777 non-null    object
#  2   Patient_name      777 non-null    object
#  3   Gender            777 non-null    object
#  4   Age               777 non-null    int64
#  5   Appointment_Date  777 non-null    object
#  6   Appointment_Time  777 non-null    object
#  7   Docter_Assigned   777 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 48.7+ KB

# %%
op.shape
# Out:
# (777, 8)

# %%
op.columns
# Out:
# Index(['s_no', 'Appointment_id', 'Patient_name', 'Gender', 'Age',
#        'Appointment_Date', 'Appointment_Time', 'Docter_Assigned'],
#       dtype='object')

# %%
op.isna().any()
# Out:
# s_no                False
# Appointment_id      False
# Patient_name        False
# Gender              False
# Age                 False
# Appointment_Date    False
# Appointment_Time    False
# Docter_Assigned     False
# dtype: bool

# %%
op.isna().any().sum()
# Out:
# 0

# %% [markdown]
# ## QUESTIONS
#
#  1) What is the distribution of male and female patients in the dataset?
#  2) On which dates do the most appointments occur?
#  3) How many patients are assigned to each doctor?
#  4) Are there specific doctors who are assigned patients based on their age or gender?

# %% [markdown]
# ##  1) What is the distribution of male and female patients in the dataset?

# %%
op.head()
# Out:
#    s_no Appointment_id      Patient_name  Gender  Age Appointment_Date  \
# 0     1           0001        Tara Varma  Female   33   \t2024-12-22\t
# 1     2           0002        Purab Garg  Female   74   \t2024-01-17\t
# 2     3           0003   Indrajit Kalita    Male   88   \t2024-12-01\t
# 3     4           0004  Dharmajan Sankar    Male    7   \t2024-02-04\t
# 4     5           0005        Samar Wali  Female   35   \t2024-11-03\t
#
#   Appointment_Time    Docter_Assigned
# 0         03:09 AM   Dr. Sunita Nair
# 1         09:44 AM  Dr. Rajesh Gupta
# 2         01:18 PM   Dr. Mohit Kumar
# 3         06:45 PM    Dr. Pooja Iyer
# 4         11:58 AM   Dr. Sunita Nair

# %%
OP = pd.DataFrame(op)

# %%
gender_distribution = OP["Gender"].value_counts()        # Gender distribution

# %%
gender_distribution
# Out:
# Gender
# Male      404
# Female    373
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    data=OP
)
plt.title("Gender_distribution")
plt.show()

# %% [markdown]
# ## 2) On which dates do the most appointments occur?

# %%
OP.head()
# Out:
#    s_no Appointment_id      Patient_name  Gender  Age Appointment_Date  \
# 0     1           0001        Tara Varma  Female   33   \t2024-12-22\t
# 1     2           0002        Purab Garg  Female   74   \t2024-01-17\t
# 2     3           0003   Indrajit Kalita    Male   88   \t2024-12-01\t
# 3     4           0004  Dharmajan Sankar    Male    7   \t2024-02-04\t
# 4     5           0005        Samar Wali  Female   35   \t2024-11-03\t
#
#   Appointment_Time    Docter_Assigned
# 0         03:09 AM   Dr. Sunita Nair
# 1         09:44 AM  Dr. Rajesh Gupta
# 2         01:18 PM   Dr. Mohit Kumar
# 3         06:45 PM    Dr. Pooja Iyer
# 4         11:58 AM   Dr. Sunita Nair

# %%
Most_appointment = OP["Appointment_Date"].value_counts()       # Calculating the number of appointments per date

# %%
Most_appointment
# Out:
# Appointment_Date
# \t2024-09-06\t    6
# \t2024-05-28\t    6
# \t2024-02-21\t    6
# \t2024-12-02\t    6
# \t2024-05-22\t    5
#                  ..
# \t2024-03-03\t    1
# \t2024-07-22\t    1
# \t2024-03-21\t    1
# \t2024-04-27\t    1
# \t2024-08-19\t    1
# Name: count, Length: 318, dtype: int64

# %%
plt.figure(figsize=(20, 10))
sns.barplot(
    data=Most_appointment
)
plt.title("Most_appointment Dates")
plt.show()
# Out:
# C:\Users\arung\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 3) How many patients are assigned to each doctor?

# %%
OP.head()
# Out:
#    s_no Appointment_id      Patient_name  Gender  Age Appointment_Date  \
# 0     1           0001        Tara Varma  Female   33   \t2024-12-22\t
# 1     2           0002        Purab Garg  Female   74   \t2024-01-17\t
# 2     3           0003   Indrajit Kalita    Male   88   \t2024-12-01\t
# 3     4           0004  Dharmajan Sankar    Male    7   \t2024-02-04\t
# 4     5           0005        Samar Wali  Female   35   \t2024-11-03\t
#
#   Appointment_Time    Docter_Assigned
# 0         03:09 AM   Dr. Sunita Nair
# 1         09:44 AM  Dr. Rajesh Gupta
# 2         01:18 PM   Dr. Mohit Kumar
# 3         06:45 PM    Dr. Pooja Iyer
# 4         11:58 AM   Dr. Sunita Nair

# %%
patients_per_doctor = OP["Docter_Assigned"].value_counts()

# %%
patients_per_doctor
# Out:
# Docter_Assigned
# Dr. Kavita Singh          121
# Dr. Pooja Iyer            106
# Dr. Arvind Mishra         101
# Dr. Sunita Nair            94
# Dr. Rajesh Gupta           92
# Dr. Mohit Kumar            92
# Dr. Rakesh Chatterjee      90
# Dr. Anjali Verma           81
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20, 8))
sns.barplot(
    data=patients_per_doctor
)
plt.title("How many patients are assigned to each doctor")
plt.show()

# %% [markdown]
# ## 4)Are there specific doctors who are assigned patients based on their age or gender

# %%
OP.head()
# Out:
#    s_no Appointment_id      Patient_name  Gender  Age Appointment_Date  \
# 0     1           0001        Tara Varma  Female   33   \t2024-12-22\t
# 1     2           0002        Purab Garg  Female   74   \t2024-01-17\t
# 2     3           0003   Indrajit Kalita    Male   88   \t2024-12-01\t
# 3     4           0004  Dharmajan Sankar    Male    7   \t2024-02-04\t
# 4     5           0005        Samar Wali  Female   35   \t2024-11-03\t
#
#   Appointment_Time    Docter_Assigned
# 0         03:09 AM   Dr. Sunita Nair
# 1         09:44 AM  Dr. Rajesh Gupta
# 2         01:18 PM   Dr. Mohit Kumar
# 3         06:45 PM    Dr. Pooja Iyer
# 4         11:58 AM   Dr. Sunita Nair

# %%
doctor_gender_distribution = OP.groupby(['Docter_Assigned', 'Gender']).size().unstack(fill_value=0)

# %%
doctor_gender_distribution
# Out:
# Gender                  Female  Male
# Docter_Assigned
# Dr. Anjali Verma            39    42
# Dr. Arvind Mishra           56    45
# Dr. Kavita Singh            62    59
# Dr. Mohit Kumar             38    54
# Dr. Pooja Iyer              51    55
# Dr. Rajesh Gupta            47    45
# Dr. Rakesh Chatterjee       40    50
# Dr. Sunita Nair             40    54

# %%
plt.figure(figsize=(12, 7))
sns.barplot(
    data=doctor_gender_distribution
)
plt.title("Are there specific doctors who are assigned patients based on their age or gender")
plt.show()

# %% [markdown]
# # --------------"PARKING_TABLE"------------

# %%
query = "select * from parking"
PK =pd.read_sql(query,db)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_18064\2400924336.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   PK =pd.read_sql(query,db)

# %%
PK.head()
# Out:
#    S_No  parking_id vehicle_number lot_id            entry_time  \
# 0     1        3810  TS 18 AU 8683    L41  \t16-10-2023 22:23\t
# 1     2        4736  AP 30 AL 3711    L13  \t04-01-2023 13:50\t
# 2     3        7712  TS 26 AQ 5851    L73  \t01-10-2023 21:13\t
# 3     4        4587  TS 27 AA 5524     L8  \t02-10-2023 21:31\t
# 4     5        4344  AP 15 AQ 4601    L99  \t26-02-2023 23:07\t
#
#               exit_time duration_hours parking_fee
# 0  \t17-10-2023 04:23\t              6         136
# 1  \t04-01-2023 20:50\t              7         125
# 2  \t02-10-2023 03:13\t              6          73
# 3  \t03-10-2023 02:31\t              5         132
# 4  \t27-02-2023 01:07\t              2          81

# %%
PK.tail()
# Out:
#       S_No  parking_id vehicle_number lot_id            entry_time  \
# 1995  1996        1983  TS 18 AO 8125   L100  \t18-06-2023 03:54\t
# 1996  1997        1376  AP 01 AQ 6712    L42  \t06-05-2023 11:47\t
# 1997  1998        7758  AP 30 AC 3114    L75  \t08-07-2023 03:23\t
# 1998  1999        1231  TS 18 AO 9358     L6  \t28-03-2023 10:42\t
# 1999  2000        1344  TS 14 AE 3184    L32  \t03-12-2023 02:58\t
#
#                  exit_time duration_hours parking_fee
# 1995  \t18-06-2023 04:54\t              1          38
# 1996  \t06-05-2023 21:47\t             10         154
# 1997  \t08-07-2023 08:23\t              5         236
# 1998  \t28-03-2023 19:42\t              9         335
# 1999  \t03-12-2023 11:58\t              9         416

# %%
PK.describe()
# Out:
#               S_No   parking_id
# count  2000.000000  2000.000000
# mean   1000.500000  5525.556000
# std     577.494589  2584.037194
# min       1.000000  1003.000000
# 25%     500.750000  3345.750000
# 50%    1000.500000  5410.500000
# 75%    1500.250000  7786.000000
# max    2000.000000  9994.000000

# %%
PK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S_No            2000 non-null   int64
#  1   parking_id      2000 non-null   int64
#  2   vehicle_number  2000 non-null   object
#  3   lot_id          2000 non-null   object
#  4   entry_time      2000 non-null   object
#  5   exit_time       2000 non-null   object
#  6   duration_hours  2000 non-null   object
#  7   parking_fee     2000 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 125.1+ KB

# %%
PK.isna().any()
# Out:
# S_No              False
# parking_id        False
# vehicle_number    False
# lot_id            False
# entry_time        False
# exit_time         False
# duration_hours    False
# parking_fee       False
# dtype: bool

# %%
PK.shape
# Out:
# (2000, 8)

# %%
PK.columns
# Out:
# Index(['S_No', 'parking_id', 'vehicle_number', 'lot_id', 'entry_time',
#        'exit_time', 'duration_hours', 'parking_fee'],
#       dtype='object')

# %%
PK.isna().sum()
# Out:
# S_No              0
# parking_id        0
# vehicle_number    0
# lot_id            0
# entry_time        0
# exit_time         0
# duration_hours    0
# parking_fee       0
# dtype: int64

# %%
pk = pd.DataFrame(PK)

# %% [markdown]
# ## QUESTIONS
#  1) What is the average parking fee collected across all records?
#  2) Which parking lot (lot_id) has the highest number of vehicles parked?
#  3) Is there a correlation between parking duration (duration_hours) and parking fee (parking_fee)?
#  4) What is highest total parking fees collected?

# %% [markdown]
# ## 1) What is the average parking fee collected across all records?

# %%
pk.head()
# Out:
#    S_No  parking_id vehicle_number lot_id            entry_time  \
# 0     1        3810  TS 18 AU 8683    L41  \t16-10-2023 22:23\t
# 1     2        4736  AP 30 AL 3711    L13  \t04-01-2023 13:50\t
# 2     3        7712  TS 26 AQ 5851    L73  \t01-10-2023 21:13\t
# 3     4        4587  TS 27 AA 5524     L8  \t02-10-2023 21:31\t
# 4     5        4344  AP 15 AQ 4601    L99  \t26-02-2023 23:07\t
#
#               exit_time duration_hours parking_fee
# 0  \t17-10-2023 04:23\t              6         136
# 1  \t04-01-2023 20:50\t              7         125
# 2  \t02-10-2023 03:13\t              6          73
# 3  \t03-10-2023 02:31\t              5         132
# 4  \t27-02-2023 01:07\t              2          81

# %%
fee = pk["parking_fee"]

# %%
fee
# Out:
# 0       136
# 1       125
# 2        73
# 3       132
# 4        81
#        ...
# 1995     38
# 1996    154
# 1997    236
# 1998    335
# 1999    416
# Name: parking_fee, Length: 2000, dtype: object

# %%
average_fee = pk["parking_fee"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 average_fee = pk["parking_fee"].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# ...

# %%
# to over come this error we should convert it into numaric

# %%
pk["parking_fee"] = pd.to_numeric(pk["parking_fee"], errors="coerce")   # Convert 'parking_fee' to numeric

# %%
average_fee = pk["parking_fee"].mean()  # Calculate the average parking fee

# %%
average_fee
# Out:
# 162.9205

# %%
average_fee.round(2)
# Out:
# 162.92

# %%
sns.barplot(data=fee)
# Out:
# <Axes: ylabel='parking_fee'>

# %% [markdown]
# ## 2) Which parking lot (lot_id) has the highest number of vehicles parked?

# %%
PK.head()
# Out:
#    S_No  parking_id vehicle_number lot_id            entry_time  \
# 0     1        3810  TS 18 AU 8683    L41  \t16-10-2023 22:23\t
# 1     2        4736  AP 30 AL 3711    L13  \t04-01-2023 13:50\t
# 2     3        7712  TS 26 AQ 5851    L73  \t01-10-2023 21:13\t
# 3     4        4587  TS 27 AA 5524     L8  \t02-10-2023 21:31\t
# 4     5        4344  AP 15 AQ 4601    L99  \t26-02-2023 23:07\t
#
#               exit_time duration_hours parking_fee
# 0  \t17-10-2023 04:23\t              6         136
# 1  \t04-01-2023 20:50\t              7         125
# 2  \t02-10-2023 03:13\t              6          73
# 3  \t03-10-2023 02:31\t              5         132
# 4  \t27-02-2023 01:07\t              2          81

# %%
No_Lots = PK.groupby('lot_id')['vehicle_number'].count()

# %%
No_Lots
# Out:
# lot_id
# L1      17
# L10     17
# L100    20
# L11     14
# L12     21
#         ..
# L95     20
# L96     19
# L97     25
# L98     14
# L99     27
# Name: vehicle_number, Length: 100, dtype: int64

# %%
max_lot = No_Lots.idxmax()

# %%
max_lot
# Out:
# 'L42'

# %%
max_count = No_Lots.max()

# %%
max_count
# Out:
# 32

# %%
print(f"Parking lot {max_lot} has the highest number of vehicles parked: {max_count}")
# Out:
# Parking lot L42 has the highest number of vehicles parked: 32

# %%
plt.figure(figsize=(8, 30))
sns.barplot(x=No_Lots.values, y=No_Lots.index, palette='viridis')
plt.title('Number of Vehicles in Each Parking Lot')
plt.ylabel('Parking Lot ID')
plt.xlabel('Number of Vehicles')
plt.show()
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_18064\1027368635.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=No_Lots.values, y=No_Lots.index, palette='viridis')

# %% [markdown]
# ##  3) Is there a correlation between parking duration (duration_hours) and parking fee (parking_fee)?

# %%
PK.head()
# Out:
#    S_No  parking_id vehicle_number lot_id            entry_time  \
# 0     1        3810  TS 18 AU 8683    L41  \t16-10-2023 22:23\t
# 1     2        4736  AP 30 AL 3711    L13  \t04-01-2023 13:50\t
# 2     3        7712  TS 26 AQ 5851    L73  \t01-10-2023 21:13\t
# 3     4        4587  TS 27 AA 5524     L8  \t02-10-2023 21:31\t
# 4     5        4344  AP 15 AQ 4601    L99  \t26-02-2023 23:07\t
#
#               exit_time duration_hours parking_fee
# 0  \t17-10-2023 04:23\t              6         136
# 1  \t04-01-2023 20:50\t              7         125
# 2  \t02-10-2023 03:13\t              6          73
# 3  \t03-10-2023 02:31\t              5         132
# 4  \t27-02-2023 01:07\t              2          81

# %%
Durations=PK['duration_hours'].describe()

# %%
Durations
# Out:
# count     2000
# unique      10
# top          4
# freq       222
# Name: duration_hours, dtype: object

# %%
D = PK[['duration_hours','parking_fee']].corr()

# %%
D
# Out:
#                 duration_hours  parking_fee
# duration_hours        1.000000     0.762853
# parking_fee           0.762853     1.000000

# %%
sns.heatmap(data=D)
# Out:
# <Axes: >

# %%
sns.lineplot(data=D)
# Out:
# <Axes: >

# %% [markdown]
# ## 4) What is highest total parking fees collected?

# %%
PK.head()
# Out:
#    S_No  parking_id vehicle_number lot_id            entry_time  \
# 0     1        3810  TS 18 AU 8683    L41  \t16-10-2023 22:23\t
# 1     2        4736  AP 30 AL 3711    L13  \t04-01-2023 13:50\t
# 2     3        7712  TS 26 AQ 5851    L73  \t01-10-2023 21:13\t
# 3     4        4587  TS 27 AA 5524     L8  \t02-10-2023 21:31\t
# 4     5        4344  AP 15 AQ 4601    L99  \t26-02-2023 23:07\t
#
#               exit_time duration_hours parking_fee
# 0  \t17-10-2023 04:23\t              6         136
# 1  \t04-01-2023 20:50\t              7         125
# 2  \t02-10-2023 03:13\t              6          73
# 3  \t03-10-2023 02:31\t              5         132
# 4  \t27-02-2023 01:07\t              2          81

# %%
Max_fee = PK['parking_fee']

# %%
Max_fee
# Out:
# 0       136
# 1       125
# 2        73
# 3       132
# 4        81
#        ...
# 1995     38
# 1996    154
# 1997    236
# 1998    335
# 1999    416
# Name: parking_fee, Length: 2000, dtype: object

# %%
plt.figure(figsize=(30, 10))
sns.barplot(x=Max_fee.values, y=Max_fee.index, palette='viridis')
plt.title('Number of Vehicles in Each Parking Lot')
plt.ylabel('Parking_fee')
plt.xlabel('Number of Vehicles')
plt.show()
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_18064\3878648559.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Max_fee.values, y=Max_fee.index, palette='viridis')

# %% [markdown]
# # --------------"PATIENT_TABLE"------------

# %%
query = "select * from patient"
PT =pd.read_sql(query,db)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_3736\431938193.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   PT =pd.read_sql(query,db)

# %%
PT.head()
# Out:
#    S_No    Patient_name  Age  Gender  Phonenumber Bloodgroup       Disease  \
# 0     1    Soumya Patil   65    Male   7962700248         A-  Hypertension
# 1     2     Arun Ponnam   18    Male   8687175475        AB-         Fever
# 2     3   Kavitha Konda   49  Female   9549704103         O-      Diabetes
# 3     4    Soumya Patil   57  Female   8146287870         A-     Arthritis
# 4     5  Pragna Malladi   35  Female   7534778680         A+        Dengue
#
#                     Email_id
# 0     soumya.patil@gmail.com
# 1      arun.ponnam@gmail.com
# 2  kavitha.konda@outlook.com
# 3     soumya.patil@email.com
# 4   pragna.malladi@yahoo.com

# %%
PT.tail()
# Out:
#      S_No     Patient_name  Age  Gender  Phonenumber Bloodgroup       Disease  \
# 995   996  Sandeep Pothula   70  Female   9774942462         B+  Tuberculosis
# 996   997     Meena Mekala   27  Female   8291049230        AB-  Hypertension
# 997   998       Bindu Meka   30  Female   7534681087         B+       Malaria
# 998   999     Geetha Chary   52  Female   7892223625        AB+     Arthritis
# 999  1000  Sandeep Malladi   44    Male   8564383050        AB+  Tuberculosis
#
#                         Email_id
# 995  sandeep.pothula@outlook.com
# 996       meena.mekala@yahoo.com
# 997         bindu.meka@email.com
# 998       geetha.chary@yahoo.com
# 999    sandeep.malladi@gmail.com

# %%
PT.describe()
# Out:
#               S_No          Age   Phonenumber
# count  1000.000000  1000.000000  1.000000e+03
# mean    500.500000    42.499000  8.483280e+09
# std     288.819436    15.937001  8.723218e+08
# min       1.000000    15.000000  7.000134e+09
# 25%     250.750000    29.000000  7.703061e+09
# 50%     500.500000    42.000000  8.487398e+09
# 75%     750.250000    56.000000  9.257710e+09
# max    1000.000000    70.000000  9.994115e+09

# %%
PT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S_No          1000 non-null   int64
#  1   Patient_name  1000 non-null   object
#  2   Age           1000 non-null   int64
#  3   Gender        1000 non-null   object
#  4   Phonenumber   1000 non-null   int64
#  5   Bloodgroup    1000 non-null   object
#  6   Disease       1000 non-null   object
#  7   Email_id      1000 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
PT.isna()
# Out:
#       S_No  Patient_name    Age  Gender  Phonenumber  Bloodgroup  Disease  \
# 0    False         False  False   False        False       False    False
# 1    False         False  False   False        False       False    False
# 2    False         False  False   False        False       False    False
# 3    False         False  False   False        False       False    False
# 4    False         False  False   False        False       False    False
# ..     ...           ...    ...     ...          ...         ...      ...
# 995  False         False  False   False        False       False    False
# 996  False         False  False   False        False       False    False
# 997  False         False  False   False        False       False    False
# 998  False         False  False   False        False       False    False
# 999  False         False  False   False        False       False    False
#
#      Email_id
# 0       False
# 1       False
# 2       False
# 3       False
# ...

# %%
PT.isna().any()
# Out:
# S_No            False
# Patient_name    False
# Age             False
# Gender          False
# Phonenumber     False
# Bloodgroup      False
# Disease         False
# Email_id        False
# dtype: bool

# %%
PT.columns
# Out:
# Index(['S_No', 'Patient_name', 'Age', 'Gender', 'Phonenumber', 'Bloodgroup',
#        'Disease', 'Email_id'],
#       dtype='object')

# %%
PT.shape
# Out:
# (1000, 8)

# %%
PT.isna().sum()
# Out:
# S_No            0
# Patient_name    0
# Age             0
# Gender          0
# Phonenumber     0
# Bloodgroup      0
# Disease         0
# Email_id        0
# dtype: int64

# %% [markdown]
# ##  QUESTIONS
#
# 1) What is the distribution of ages among the patients?
# 2) How is the distribution of diseases different between male and female patients?
# 3) What is the frequency of each blood group in the dataset?
# 4) Which diseases are most commonly diagnosed among the patients? Is there any correlation between age or blood group and disease type?
# 5) Are there any duplicate records in the dataset?

# %% [markdown]
# ## 1) What is the distribution of ages among the patients?

# %%
PT.head()
# Out:
#    S_No    Patient_name  Age  Gender  Phonenumber Bloodgroup       Disease  \
# 0     1    Soumya Patil   65    Male   7962700248         A-  Hypertension
# 1     2     Arun Ponnam   18    Male   8687175475        AB-         Fever
# 2     3   Kavitha Konda   49  Female   9549704103         O-      Diabetes
# 3     4    Soumya Patil   57  Female   8146287870         A-     Arthritis
# 4     5  Pragna Malladi   35  Female   7534778680         A+        Dengue
#
#                     Email_id Age_Group
# 0     soumya.patil@gmail.com       61+
# 1      arun.ponnam@gmail.com      0-20
# 2  kavitha.konda@outlook.com     41-60
# 3     soumya.patil@email.com     41-60
# 4   pragna.malladi@yahoo.com     21-40

# %%
bins = [0, 20, 40, 60, 100]
labels = ["0-20", "21-40", "41-60", "61+"]

# %%
PT["Age_Group"] = pd.cut(PT["Age"], bins=bins, labels=labels, right=False)

# %%
age_distribution = PT["Age_Group"].value_counts().sort_index()

# %%
age_distribution
# Out:
# Age_Group
# 0-20      83
# 21-40    374
# 41-60    350
# 61+      193
# Name: count, dtype: int64

# %%
age_distribution.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Age Distribution of Patients")
plt.xlabel("Age Group")
plt.ylabel("Number of Patients")
plt.xticks(rotation=0)
plt.show()

# %%
sns.barplot(data=age_distribution)
# Out:
# <Axes: xlabel='Age_Group', ylabel='count'>

# %% [markdown]
# ## 2) How is the distribution of diseases different between male and female patients?

# %%
PT.head()
# Out:
#    S_No    Patient_name  Age  Gender  Phonenumber Bloodgroup       Disease  \
# 0     1    Soumya Patil   65    Male   7962700248         A-  Hypertension
# 1     2     Arun Ponnam   18    Male   8687175475        AB-         Fever
# 2     3   Kavitha Konda   49  Female   9549704103         O-      Diabetes
# 3     4    Soumya Patil   57  Female   8146287870         A-     Arthritis
# 4     5  Pragna Malladi   35  Female   7534778680         A+        Dengue
#
#                     Email_id Age_Group
# 0     soumya.patil@gmail.com       61+
# 1      arun.ponnam@gmail.com      0-20
# 2  kavitha.konda@outlook.com     41-60
# 3     soumya.patil@email.com     41-60
# 4   pragna.malladi@yahoo.com     21-40

# %%
disease_distribution = PT.groupby(["Gender", "Disease"]).size().unstack(fill_value=0)

# %%
disease_distribution
# Out:
# Disease  Anemia  Arthritis  Asthma  Covid-19  Dengue  Diabetes  Fever  \
# Gender
# Female       43         53      51        48      46        69      0
# Male         52         41      51        44      41        54      1
#
# Disease  Hypertension  Malaria  Migraine  Tuberculosis
# Gender
# Female             52       43        51            46
# Male               53       52        53            56

# %%
plt.figure(figsize=(25, 10))
sns.boxplot(data=disease_distribution)
# Out:
# <Axes: xlabel='Disease'>

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=disease_distribution)
# Out:
# <Axes: xlabel='Disease'>

# %% [markdown]
# ## 3) What is the frequency of each blood group in the dataset?

# %%
PT.head()
# Out:
#    S_No    Patient_name  Age  Gender  Phonenumber Bloodgroup       Disease  \
# 0     1    Soumya Patil   65    Male   7962700248         A-  Hypertension
# 1     2     Arun Ponnam   18    Male   8687175475        AB-         Fever
# 2     3   Kavitha Konda   49  Female   9549704103         O-      Diabetes
# 3     4    Soumya Patil   57  Female   8146287870         A-     Arthritis
# 4     5  Pragna Malladi   35  Female   7534778680         A+        Dengue
#
#                     Email_id Age_Group
# 0     soumya.patil@gmail.com       61+
# 1      arun.ponnam@gmail.com      0-20
# 2  kavitha.konda@outlook.com     41-60
# 3     soumya.patil@email.com     41-60
# 4   pragna.malladi@yahoo.com     21-40

# %%
blood_group_counts = PT["Bloodgroup"].value_counts()

# %%
blood_group_counts
# Out:
# Bloodgroup
# AB-    140
# O-     137
# AB+    132
# B-     131
# A-     130
# A+     119
# O+     107
# B+     104
# Name: count, dtype: int64

# %%
sns.barplot(data=blood_group_counts)
# Out:
# <Axes: xlabel='Bloodgroup', ylabel='count'>

# %% [markdown]
# ## 4) Which diseases are most commonly diagnosed among the patients? Is there any correlation between age or blood group and disease type?

# %%
PT.head()
# Out:
#    S_No    Patient_name  Age  Gender  Phonenumber Bloodgroup       Disease  \
# 0     1    Soumya Patil   65    Male   7962700248         A-  Hypertension
# 1     2     Arun Ponnam   18    Male   8687175475        AB-         Fever
# 2     3   Kavitha Konda   49  Female   9549704103         O-      Diabetes
# 3     4    Soumya Patil   57  Female   8146287870         A-     Arthritis
# 4     5  Pragna Malladi   35  Female   7534778680         A+        Dengue
#
#                     Email_id Age_Group
# 0     soumya.patil@gmail.com       61+
# 1      arun.ponnam@gmail.com      0-20
# 2  kavitha.konda@outlook.com     41-60
# 3     soumya.patil@email.com     41-60
# 4   pragna.malladi@yahoo.com     21-40

# %%
disease_counts = PT["Disease"].value_counts()    # to get Most common diseases

# %%
disease_counts
# Out:
# Disease
# Diabetes        123
# Hypertension    105
# Migraine        104
# Asthma          102
# Tuberculosis    102
# Anemia           95
# Malaria          95
# Arthritis        94
# Covid-19         92
# Dengue           87
# Fever             1
# Name: count, dtype: int64

# %%
age_disease_correlation = PT.groupby("Disease")["Age"].mean()   # Correlation between age and disease

# %%
age_disease_correlation
# Out:
# Disease
# Anemia          42.231579
# Arthritis       42.404255
# Asthma          40.774510
# Covid-19        45.152174
# Dengue          43.172414
# Diabetes        42.804878
# Fever           18.000000
# Hypertension    41.085714
# Malaria         41.094737
# Migraine        43.240385
# Tuberculosis    43.470588
# Name: Age, dtype: float64

# %%
# Correlation between blood group and disease
blood_disease_correlation = PT.groupby(["Bloodgroup", "Disease"]).size().unstack(fill_value=0)

# %%
blood_disease_correlation
# Out:
# Disease     Anemia  Arthritis  Asthma  Covid-19  Dengue  Diabetes  Fever  \
# Bloodgroup
# A+              19          7      16         9       9        13      0
# A-               8         17       8         9      13        16      0
# AB+             10         11      11        24       4        15      0
# AB-             15          8      24        11      11        20      1
# B+              10         10      12         9      12        17      0
# B-              13         13      10         9      13        11      0
# O+               9         13      11         2      11        14      0
# O-              11         15      10        19      14        17      0
#
# Disease     Hypertension  Malaria  Migraine  Tuberculosis
# Bloodgroup
# A+                    13       13         9            11
# A-                    13       18        12            16
# AB+                   14        9        14            20
# ...

# %%
plt.figure(figsize=(25, 10))
sns.barplot(data=blood_disease_correlation)
# Out:
# <Axes: xlabel='Disease'>

# %%
sns.heatmap(data=blood_disease_correlation)
# Out:
# <Axes: xlabel='Disease', ylabel='Bloodgroup'>

# %% [markdown]
# ## 5) Are there any duplicate records in the dataset?

# %%
PT.head()
# Out:
#    S_No    Patient_name  Age  Gender  Phonenumber Bloodgroup       Disease  \
# 0     1    Soumya Patil   65    Male   7962700248         A-  Hypertension
# 1     2     Arun Ponnam   18    Male   8687175475        AB-         Fever
# 2     3   Kavitha Konda   49  Female   9549704103         O-      Diabetes
# 3     4    Soumya Patil   57  Female   8146287870         A-     Arthritis
# 4     5  Pragna Malladi   35  Female   7534778680         A+        Dengue
#
#                     Email_id Age_Group
# 0     soumya.patil@gmail.com       61+
# 1      arun.ponnam@gmail.com      0-20
# 2  kavitha.konda@outlook.com     41-60
# 3     soumya.patil@email.com     41-60
# 4   pragna.malladi@yahoo.com     21-40

# %%
duplicates = PT.duplicated()                    # Check for duplicate records

# %%
duplicate_rows = PT[duplicates]               # Display duplicate rows

# %%
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [S_No, Patient_name, Age, Gender, Phonenumber, Bloodgroup, Disease, Email_id, Age_Group]
# Index: []

# %%
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [S_No, Patient_name, Age, Gender, Phonenumber, Bloodgroup, Disease, Email_id, Age_Group]
# Index: []

# %%
sns.barplot(data=duplicate_rows)
# Out:
# <Axes: >

# %%
pharmacy

# %% [markdown]
# # --------------"PATIENT_TABLE"-----------

# %%
query = "select * from pharmacy"
PH =pd.read_sql(query,db)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_3736\2346276718.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   PH =pd.read_sql(query,db)

# %%
PH.head()
# Out:
#    Medicine_ID Medicine_Name                     Privention    Dose  \
# 0          100  Prednisolone           Prevents blood clots   250mg
# 1          101  Prednisolone  Reduces inflammation and pain   250mg
# 2          102     Vitamin C     Treats high blood pressure   500mg
# 3          103     Ibuprofen              Strengthens bones   500mg
# 4          104    Omeprazole  Treats acid reflux and ulcers  1000mg
#
#        Category        Manufacture Manufactured Expiry_Date  Quantity  Price
# 0    Painkiller     Wellness Corp.   2022-05-09  2024-11-12       428  46.25
# 1  Antidiabetic      Global Pharma   2022-03-14  2024-09-21       335  45.94
# 2       Antacid      Global Pharma   2022-12-17  2025-07-04       157  27.08
# 3       Vitamin  Diabetes Care Co.   2022-04-05  2025-06-07       170  37.32
# 4       Mineral         ABC Pharma   2023-12-29  2024-10-28       203  12.84

# %%
PH.tail()
# Out:
#      Medicine_ID Medicine_Name                           Privention    Dose  \
# 295          395   Doxycycline                   Lowers cholesterol   500mg
# 296          396    Lisinopril           Used for managing diabetes  1000mg
# 297          397  Atorvastatin          Treats bacterial infections   500mg
# 298          398  Atorvastatin  Antibiotic for bacterial infections   500mg
# 299          399    Cetirizine                   Lowers cholesterol   500mg
#
#            Category          Manufacture Manufactured Expiry_Date  Quantity  \
# 295  Cardiovascular           ABC Pharma   2023-06-19  2026-06-19       490
# 296         Vitamin      HealthCare Inc.   2022-09-23  2025-01-19        71
# 297         Steroid  Natural Health Ltd.   2023-10-05  2025-02-03       177
# 298         Mineral    Diabetes Care Co.   2023-04-07  2024-02-19       451
# 299   Antihistamine    Diabetes Care Co.   2023-12-25  2025-12-30       179
#
#      Price
# 295  11.00
# 296  34.77
# 297  27.85
# ...

# %%
PH.describe()
# Out:
#        Medicine_ID    Quantity       Price
# count   300.000000  300.000000  300.000000
# mean    249.500000  267.250000   27.633133
# std      86.746758  127.645389   13.130948
# min     100.000000   50.000000    5.150000
# 25%     174.750000  160.500000   16.745000
# 50%     249.500000  259.500000   27.620000
# 75%     324.250000  373.250000   38.655000
# max     399.000000  500.000000   49.990000

# %%
PH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Medicine_ID    300 non-null    int64
#  1   Medicine_Name  300 non-null    object
#  2   Privention     300 non-null    object
#  3   Dose           300 non-null    object
#  4   Category       296 non-null    object
#  5   Manufacture    299 non-null    object
#  6   Manufactured   300 non-null    object
#  7   Expiry_Date    300 non-null    object
#  8   Quantity       300 non-null    int64
#  9   Price          300 non-null    float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 23.6+ KB

# %%
PH.isna().any()
# Out:
# Medicine_ID      False
# Medicine_Name    False
# Privention       False
# Dose             False
# Category          True
# Manufacture       True
# Manufactured     False
# Expiry_Date      False
# Quantity         False
# Price            False
# dtype: bool

# %%
PH.isna().sum()
# Out:
# Medicine_ID      0
# Medicine_Name    0
# Privention       0
# Dose             0
# Category         4
# Manufacture      1
# Manufactured     0
# Expiry_Date      0
# Quantity         0
# Price            0
# dtype: int64

# %%
PH.shape
# Out:
# (300, 10)

# %%
PH.fillna(method = "ffill",inplace = True)
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_3736\1914233345.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   PH.fillna(method = "ffill",inplace = True)

# %%
PH.isna().any()
# Out:
# Medicine_ID      False
# Medicine_Name    False
# Privention       False
# Dose             False
# Category         False
# Manufacture      False
# Manufactured     False
# Expiry_Date      False
# Quantity         False
# Price            False
# dtype: bool

# %%
PH.isna().sum()
# Out:
# Medicine_ID      0
# Medicine_Name    0
# Privention       0
# Dose             0
# Category         0
# Manufacture      0
# Manufactured     0
# Expiry_Date      0
# Quantity         0
# Price            0
# dtype: int64

# %%
PH.shape
# Out:
# (300, 10)

# %% [markdown]
# ## QUESTION
#
# 1) What is the distribution of medicine prices? Are there significant variations between different categories?
# 2) Which medicines have the highest and lowest quantities in stock?
# 3) How many medicines are nearing their expiry date ?
# 4) Which manufacturer produces the most medicines in the dataset? How does the quantity and price distribution vary by manufacturer?
# 5) What is the average price and quantity of medicines in each category? Are certain categories more expensive or more abundant?

# %% [markdown]
# ## 1) What is the distribution of medicine prices? Are there significant variations between different categories?

# %%
PH.head()
# Out:
#    Medicine_ID Medicine_Name                     Privention    Dose  \
# 0          100  Prednisolone           Prevents blood clots   250mg
# 1          101  Prednisolone  Reduces inflammation and pain   250mg
# 2          102     Vitamin C     Treats high blood pressure   500mg
# 3          103     Ibuprofen              Strengthens bones   500mg
# 4          104    Omeprazole  Treats acid reflux and ulcers  1000mg
#
#        Category        Manufacture Manufactured Expiry_Date  Quantity  Price
# 0    Painkiller     Wellness Corp.   2022-05-09  2024-11-12       428  46.25
# 1  Antidiabetic      Global Pharma   2022-03-14  2024-09-21       335  45.94
# 2       Antacid      Global Pharma   2022-12-17  2025-07-04       157  27.08
# 3       Vitamin  Diabetes Care Co.   2022-04-05  2025-06-07       170  37.32
# 4       Mineral         ABC Pharma   2023-12-29  2024-10-28       203  12.84

# %%
price_summary = PH.groupby("Category")["Price"].describe()

# %%
price_summary
# Out:
#                 count       mean        std   min      25%     50%     75%  \
# Category
# Antacid          19.0  25.779474  12.552725  5.90  16.3400  26.000  35.850
# Antibiotic       23.0  28.740000  11.101497  7.58  22.0450  31.960  35.990
# Antidiabetic     34.0  29.667941  12.112547  5.28  22.0650  29.510  38.620
# Antihistamine    23.0  22.543913  11.936243  5.47  13.7700  20.980  28.815
# Cardiovascular   33.0  25.295455  14.532647  5.15  12.0800  23.680  39.040
# Mineral          38.0  24.792105  13.742364  5.40  15.6050  18.590  36.360
# Painkiller       29.0  26.337241  13.163426  5.58  17.3000  25.340  37.840
# Steroid          31.0  32.151613  12.921408  5.61  22.1600  34.550  42.755
# Supplement       30.0  27.361333  12.862430  5.40  16.9400  25.865  37.880
# Vitamin          40.0  31.343000  13.468724  6.24  22.1175  35.815  42.000
#
#                   max
# Category
# Antacid         48.28
# Antibiotic      46.22
# Antidiabetic    49.83
# Antihistamine   49.67
# ...

# %%
print(price_summary)
# Out:
#                 count       mean        std   min      25%     50%     75%  \
# Category
# Antacid          19.0  25.779474  12.552725  5.90  16.3400  26.000  35.850
# Antibiotic       23.0  28.740000  11.101497  7.58  22.0450  31.960  35.990
# Antidiabetic     34.0  29.667941  12.112547  5.28  22.0650  29.510  38.620
# Antihistamine    23.0  22.543913  11.936243  5.47  13.7700  20.980  28.815
# Cardiovascular   33.0  25.295455  14.532647  5.15  12.0800  23.680  39.040
# Mineral          38.0  24.792105  13.742364  5.40  15.6050  18.590  36.360
# Painkiller       29.0  26.337241  13.163426  5.58  17.3000  25.340  37.840
# Steroid          31.0  32.151613  12.921408  5.61  22.1600  34.550  42.755
# Supplement       30.0  27.361333  12.862430  5.40  16.9400  25.865  37.880
# Vitamin          40.0  31.343000  13.468724  6.24  22.1175  35.815  42.000
#
#                   max
# Category
# Antacid         48.28
# Antibiotic      46.22
# Antidiabetic    49.83
# Antihistamine   49.67
# ...

# %%
sns.barplot(data=PH)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="Category", y="Price", data=PH, palette="Set2")
plt.title("Price Variation Across Categories")
plt.xlabel("Category")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\arung\AppData\Local\Temp\ipykernel_3736\4183889300.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Category", y="Price", data=PH, palette="Set2")

# %% [markdown]
# ## 2) Which medicines have the highest and lowest quantities in stock?

# %%
PH.head()
# Out:
#    Medicine_ID Medicine_Name                     Privention    Dose  \
# 0          100  Prednisolone           Prevents blood clots   250mg
# 1          101  Prednisolone  Reduces inflammation and pain   250mg
# 2          102     Vitamin C     Treats high blood pressure   500mg
# 3          103     Ibuprofen              Strengthens bones   500mg
# 4          104    Omeprazole  Treats acid reflux and ulcers  1000mg
#
#        Category        Manufacture Manufactured Expiry_Date  Quantity  Price
# 0    Painkiller     Wellness Corp.   2022-05-09  2024-11-12       428  46.25
# 1  Antidiabetic      Global Pharma   2022-03-14  2024-09-21       335  45.94
# 2       Antacid      Global Pharma   2022-12-17  2025-07-04       157  27.08
# 3       Vitamin  Diabetes Care Co.   2022-04-05  2025-06-07       170  37.32
# 4       Mineral         ABC Pharma   2023-12-29  2024-10-28       203  12.84

# %%
highest_quantity = PH.loc[PH['Quantity'].idxmax()]                                      # Identify the medicine with the highest quantities

# %%
highest_quantity
# Out:
# Medicine_ID                                 201
# Medicine_Name                 Calcium Carbonate
# Privention       Used to relieve pain and fever
# Dose                                      500mg
# Category                                Vitamin
# Manufacture                  MediCare Pvt. Ltd.
# Manufactured                         2023-12-24
# Expiry_Date                          2026-02-22
# Quantity                                    500
# Price                                     22.48
# Name: 101, dtype: object

# %%
lowest_quantity = PH.loc[PH['Quantity'].idxmin()]                                  # Identify the medicine with the lowest quantities

# %%
lowest_quantity
# Out:
# Medicine_ID                        293
# Medicine_Name             Prednisolone
# Privention       Relaxes blood vessels
# Dose                            1000mg
# Category                    Painkiller
# Manufacture        Natural Health Ltd.
# Manufactured                2023-04-06
# Expiry_Date                 2026-02-25
# Quantity                            50
# Price                             6.09
# Name: 193, dtype: object

# %% [markdown]
# ## 3) How many medicines are nearing their expiry date ?

# %%
PH.head()
# Out:
#    Medicine_ID Medicine_Name                     Privention    Dose  \
# 0          100  Prednisolone           Prevents blood clots   250mg
# 1          101  Prednisolone  Reduces inflammation and pain   250mg
# 2          102     Vitamin C     Treats high blood pressure   500mg
# 3          103     Ibuprofen              Strengthens bones   500mg
# 4          104    Omeprazole  Treats acid reflux and ulcers  1000mg
#
#        Category        Manufacture Manufactured Expiry_Date  Quantity  Price
# 0    Painkiller     Wellness Corp.   2022-05-09  2024-11-12       428  46.25
# 1  Antidiabetic      Global Pharma   2022-03-14  2024-09-21       335  45.94
# 2       Antacid      Global Pharma   2022-12-17  2025-07-04       157  27.08
# 3       Vitamin  Diabetes Care Co.   2022-04-05  2025-06-07       170  37.32
# 4       Mineral         ABC Pharma   2023-12-29  2024-10-28       203  12.84

# %%
 # Convert Expiry_Date to datetime
PH['Expiry_Date'] = pd.to_datetime(PH['Expiry_Date'])

# %%
from datetime import datetime, timedelta

# %%
# Get today's date
today = datetime.today()
threshold_date = today + timedelta(days=90)

# %%
nearing_expiry = PH[PH['Expiry_Date'] <= threshold_date]

# Count how many medicines are nearing expiry
nearing_expiry_count = nearing_expiry.shape[0]

# %%
nearing_expiry_count
# Out:
# 138
